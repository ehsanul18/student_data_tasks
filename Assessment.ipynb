# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import LabelEncoder

# %%
# import chardet

# file = "../Datasets/dataset-student-english.xlsx"

# with open(file, 'rb') as rawdata:
#     result = chardet.detect(rawdata.read(100000))
# result

d_s = pd.read_csv("../Datasets/Dataset-students.csv")
d_s_m = pd.read_csv("../Datasets/dataset-student-math.csv")
d_s_e = pd.read_csv("../Datasets/dataset-student-english.csv")

# %%
d_s.head()
# Out:
#    Student Id school sex  age address famsize Pstatus  Medu  Fedu     Mjob  \
# 0           1     GP   F   18       U     GT3       A     4     4  at_home
# 1           2     GP   F   17       U     GT3       T     1     1  at_home
# 2           3     GP   F   15       U     LE3       T     1     1  at_home
# 3           4     GP   F   15       U     GT3       T     4     2   health
# 4           5     GP   F   16       U     GT3       T     3     3    other
#
#    ... higher internet romantic  famrel  freetime  goout Dalc Walc health  \
# 0  ...    yes       no       no       4         3      4    1    1      3
# 1  ...    yes      yes       no       5         3      3    1    1      3
# 2  ...    yes      yes       no       4         3      2    2    3      3
# 3  ...    yes      yes      yes       3         2      2    1    1      5
# 4  ...    yes       no       no       4         3      2    1    2      5
#
#   absences
# 0        6
# 1        4
# 2       10
# 3        2
# ...

# %%
d_s_m.head()
# Out:
#    Student Id  G1  G2  G3
# 0           1   5   6   6
# 1           2   5   5   6
# 2           3   7   8  10
# 3           4  15  14  15
# 4           5   6  10  10

# %%
d_s_e.head()
# Out:
#    Student Id  G1  G2  G3
# 0           1   0  11  11
# 1           2   9  11  11
# 2           3  12  13  12
# 3           4  14  14  14
# 4           5  11  13  13

# %%
d_s.describe()
# Out:
#        Student Id         age        Medu        Fedu  traveltime   studytime  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean   198.000000   16.696203    2.749367    2.521519    1.448101    2.035443
# std    114.170924    1.276043    1.094735    1.088201    0.697505    0.839240
# min      1.000000   15.000000    0.000000    0.000000    1.000000    1.000000
# 25%     99.500000   16.000000    2.000000    2.000000    1.000000    1.000000
# 50%    198.000000   17.000000    3.000000    2.000000    1.000000    2.000000
# 75%    296.500000   18.000000    4.000000    3.000000    2.000000    2.000000
# max    395.000000   22.000000    4.000000    4.000000    4.000000    4.000000
#
#          failures      famrel    freetime       goout        Dalc        Walc  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     0.334177    3.944304    3.235443    3.108861    1.481013    2.291139
# ...

# %%
d_s_m.describe()
# Out:
#        Student Id          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000
# mean   198.000000   10.908861   10.713924   10.415190
# std    114.170924    3.319195    3.761505    4.581443
# min      1.000000    3.000000    0.000000    0.000000
# 25%     99.500000    8.000000    9.000000    8.000000
# 50%    198.000000   11.000000   11.000000   11.000000
# 75%    296.500000   13.000000   13.000000   14.000000
# max    395.000000   19.000000   19.000000   20.000000

# %%
d_s_e.describe()
# Out:
#        Student Id          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000
# mean   198.000000   12.005063   12.035443   12.460759
# std    114.170924    2.420298    2.417945    2.604244
# min      1.000000    0.000000    6.000000    0.000000
# 25%     99.500000   10.000000   10.000000   11.000000
# 50%    198.000000   12.000000   12.000000   12.000000
# 75%    296.500000   14.000000   13.000000   14.000000
# max    395.000000   18.000000   19.000000   19.000000

# %%
d_s.isnull().sum()
# Out:
# Student Id    0
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        5
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# dtype: int64

# %%
d_s_m.isnull().sum()
# Out:
# Student Id    0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
d_s_e.isnull().sum()
# Out:
# Student Id    0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
d_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student Id  395 non-null    int64
#  1   school      395 non-null    object
#  2   sex         395 non-null    object
#  3   age         395 non-null    int64
#  4   address     395 non-null    object
#  5   famsize     395 non-null    object
#  6   Pstatus     395 non-null    object
#  7   Medu        395 non-null    int64
#  8   Fedu        395 non-null    int64
#  9   Mjob        395 non-null    object
#  10  Fjob        395 non-null    object
#  11  reason      395 non-null    object
#  12  guardian    395 non-null    object
#  13  traveltime  395 non-null    int64
#  14  studytime   395 non-null    int64
#  15  failures    395 non-null    int64
#  16  schoolsup   395 non-null    object
#  17  famsup      390 non-null    object
#  18  paid        395 non-null    object
# ...

# %%
list_of_objects = d_s.select_dtypes(include=['object']).columns
list_of_objects
# Out:
# Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='object')

# %%
merge_ini_math = pd.merge(d_s, d_s_m, how='inner', on='Student Id')
merge_ini_math
# Out:
#      Student Id school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0             1     GP   F   18       U     GT3       A     4     4   at_home
# 1             2     GP   F   17       U     GT3       T     1     1   at_home
# 2             3     GP   F   15       U     LE3       T     1     1   at_home
# 3             4     GP   F   15       U     GT3       T     4     2    health
# 4             5     GP   F   16       U     GT3       T     3     3     other
# ..          ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 390         391     MS   M   20       U     LE3       A     2     2  services
# 391         392     MS   M   17       U     LE3       T     3     1  services
# 392         393     MS   M   21       R     GT3       T     1     1     other
# 393         394     MS   M   18       R     LE3       T     3     2  services
# 394         395     MS   M   19       U     LE3       T     1     1     other
#
# ...

# %%
male_v_female_final = merge_ini_math[['sex', 'G3']]
male_v_female_final
# Out:
#     sex  G3
# 0     F   6
# 1     F   6
# 2     F  10
# 3     F  15
# 4     F  10
# ..   ..  ..
# 390   M   9
# 391   M  16
# 392   M   7
# 393   M  10
# 394   M   9
#
# [395 rows x 2 columns]

# %%
mean_male = male_v_female_final[male_v_female_final.sex == 'M'].G3.mean()
mean_female = male_v_female_final[male_v_female_final.sex == 'F'].G3.mean()

# %%
mean_male - mean_female
# Out:
# 0.9480923488276431

# %%
g2_g3 = pd.DataFrame(merge_ini_math.G2 > merge_ini_math.G3)
g2_g3 = g2_g3.set_index(0)
len(g2_g3.loc[True])
# Out:
# 90

# %%
merge_ini_math[['absences', 'G3']].corr()['absences']
# Out:
# absences    1.000000
# G3          0.034247
# Name: absences, dtype: float64

# %%
merge_math_english = pd.merge(d_s_m, d_s_e, how='inner', on='Student Id')
merge_math_english
# Out:
#      Student Id  G1_x  G2_x  G3_x  G1_y  G2_y  G3_y
# 0             1     5     6     6     0    11    11
# 1             2     5     5     6     9    11    11
# 2             3     7     8    10    12    13    12
# 3             4    15    14    15    14    14    14
# 4             5     6    10    10    11    13    13
# ..          ...   ...   ...   ...   ...   ...   ...
# 390         391     9     9     9    14    13    14
# 391         392    14    16    16    11    13    14
# 392         393    10     8     7    12    13    15
# 393         394    11    12    10    14    14    15
# 394         395     8     9     9    14    14    16
#
# [395 rows x 7 columns]

# %%
merge_math_english['G3_x'].loc[16]

merge_math_english['G3_y'].loc[merge_math_english['G3_x'] == 16].mode()
# Out:
# 0    14
# dtype: int64

# %%
merge_math_english.head(30)
# Out:
#     Student Id  G1_x  G2_x  G3_x  G1_y  G2_y  G3_y
# 0            1     5     6     6     0    11    11
# 1            2     5     5     6     9    11    11
# 2            3     7     8    10    12    13    12
# 3            4    15    14    15    14    14    14
# 4            5     6    10    10    11    13    13
# 5            6    15    15    15    12    12    13
# 6            7    12    12    11    13    12    13
# 7            8     6     5     6    10    13    13
# 8            9    16    18    19    15    16    17
# 9           10    14    15    15    12    12    13
# 10          11    10     8     9    14    14    14
# 11          12    10    12    12    10    12    13
# 12          13    14    14    14    12    13    12
# 13          14    10    10    11    12    12    13
# 14          15    14    16    16    14    14    15
# 15          16    14    14    14    17    17    17
# 16          17    13    14    14    13    13    14
# ...

# %%
d_s_m.sort_values('G3', ascending = False).head(20)
# Out:
#      Student Id  G1  G2  G3
# 47           48  19  19  20
# 113         114  18  19  19
# 110         111  18  19  19
# 286         287  18  18  19
# 8             9  16  18  19
# 374         375  19  18  19
# 91           92  16  17  18
# 42           43  19  18  18
# 36           37  15  16  18
# 129         130  18  18  18
# 107         108  16  18  18
# 104         105  16  18  18
# 198         199  18  18  18
# 293         294  18  18  18
# 306         307  17  18  18
# 303         304  17  17  18
# 245         246  18  18  18
# 260         261  17  18  18
# 222         223  16  16  17
# 31           32  17  16  17

# %%
merge_math_english.sort_values('G3_x', ascending=False).head(50)
# Out:
#      Student Id  G1_x  G2_x  G3_x  G1_y  G2_y  G3_y
# 47           48    19    19    20    17    17    17
# 113         114    18    19    19    18    17    18
# 110         111    18    19    19    13    14    14
# 286         287    18    18    19    12    12    13
# 8             9    16    18    19    15    16    17
# 374         375    19    18    19    17    18    17
# 91           92    16    17    18    14    13    13
# 42           43    19    18    18    14    15    15
# 36           37    15    16    18    14    14    14
# 129         130    18    18    18    13    12    13
# 107         108    16    18    18    13    14    14
# 104         105    16    18    18    16    16    16
# 198         199    18    18    18    14    15    16
# 293         294    18    18    18    11    12    14
# 306         307    17    18    18    15    16    16
# 303         304    17    17    18    15    12    13
# 245         246    18    18    18    12    13    13
# ...

# %%
d_s_m.G3.quantile([0.75])
# Out:
# 0.75    14.0
# Name: G3, dtype: float64

# %%
merge_ini_english = pd.merge(d_s, d_s_e, how='inner', on='Student Id')
merge_ini_english
# Out:
#      Student Id school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0             1     GP   F   18       U     GT3       A     4     4   at_home
# 1             2     GP   F   17       U     GT3       T     1     1   at_home
# 2             3     GP   F   15       U     LE3       T     1     1   at_home
# 3             4     GP   F   15       U     GT3       T     4     2    health
# 4             5     GP   F   16       U     GT3       T     3     3     other
# ..          ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 390         391     MS   M   20       U     LE3       A     2     2  services
# 391         392     MS   M   17       U     LE3       T     3     1  services
# 392         393     MS   M   21       R     GT3       T     1     1     other
# 393         394     MS   M   18       R     LE3       T     3     2  services
# 394         395     MS   M   19       U     LE3       T     1     1     other
#
# ...

# %%
merge_ini_english_age = merge_ini_english[['age', 'G3']]
merge_ini_english_age
# Out:
#      age  G3
# 0     18  11
# 1     17  11
# 2     15  12
# 3     15  14
# 4     16  13
# ..   ...  ..
# 390   20  14
# 391   17  14
# 392   21  15
# 393   18  15
# 394   19  16
#
# [395 rows x 2 columns]

# %%
merge_ini_english_age.sort_values('G3', ascending=False).head(50)
# Out:
#      age  G3
# 338   18  19
# 185   17  18
# 349   18  18
# 337   17  18
# 314   19  18
# 332   18  18
# 327   17  18
# 181   16  18
# 113   15  18
# 335   17  17
# 364   17  17
# 343   17  17
# 344   18  17
# 289   18  17
# 356   17  17
# 47    16  17
# 359   18  17
# 240   17  17
# 357   17  17
# 378   18  17
# 15    16  17
# 183   17  17
# 374   18  17
# 8     15  17
# 196   17  17
# 365   18  17
# 238   17  16
# 104   15  16
# 51    15  16
# 316   18  16
# 101   16  16
# 312   19  16
# 59    16  16
# 60    16  16
# 61    16  16
# 198   17  16
# 306   20  16
# 65    16  16
# 296   19  16
# 201   16  16
# 276   18  16
# 250   18  16
# 209   17  16
# 243   16  16
# 212   16  16
# 394   19  16
# 57    15  16
# 116   15  16
# 348   17  16
# 336   19  16

# %%
merge_ini_english_age[merge_ini_english_age['G3'] == 17]
# Out:
#      age  G3
# 8     15  17
# 15    16  17
# 47    16  17
# 183   17  17
# 196   17  17
# 240   17  17
# 289   18  17
# 335   17  17
# 343   17  17
# 344   18  17
# 356   17  17
# 357   17  17
# 359   18  17
# 364   17  17
# 365   18  17
# 374   18  17
# 378   18  17

# %%
plt.figure(figsize=(10,10))
sns.set_theme(style="whitegrid")
ax = sns.countplot(x="age", data=d_s)
plt.xlabel("Age")
plt.ylabel("Number of students in different ages")
plt.title("Age distribution in bar chart")
# Out:
# Text(0.5, 1.0, 'Age distribution in bar chart')

# %%
d_s_e.G3.std()
# Out:
# 2.6042437896866653

# %%
plt.figure(figsize=(10,10))
ax = sns.boxplot(x=d_s_m["G3"])
plt.title("Box plot to detect outliers")
# Out:
# Text(0.5, 1.0, 'Box plot to detect outliers')

# %%
merge_math_english['G2_x'].mean()
# Out:
# 10.713924050632912

# %%
merge_math_english['G2_y'].mean()
# Out:
# 12.035443037974684

# %%
d_s.isnull().sum()
# Out:
# Student Id    0
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        5
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# dtype: int64

# %%
plt.figure(figsize=(10,10))
ax = sns.boxplot(x=merge_ini_math["school"], y=merge_ini_math["G3"])
plt.title("Box plot of Math final grade distribution based on school")
# Out:
# Text(0.5, 1.0, 'Box plot of Math final grade distribution based on school')

# %%
plt.figure(figsize=(10,10))
ax = sns.boxplot(x=merge_ini_math["address"], y=merge_ini_math["G3"])
plt.title("Box plot of Math final grade distribution based on address")
# Out:
# Text(0.5, 1.0, 'Box plot of Math final grade distribution based on address')

# %%
list_of_objects = merge_ini_math.select_dtypes(include=['object']).columns
list_of_objects
# Out:
# Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='object')

# %%
x_values = ['school', 'sex', 'address', 'Pstatus']

merge_ini_math_encoded = merge_ini_math

le = LabelEncoder()

for i in x_values:
    merge_ini_math_encoded[i] = le.fit_transform(merge_ini_math_encoded[i])

# %%
merge_ini_math.Pstatus.value_counts()
# Out:
# 1    354
# 0     41
# Name: Pstatus, dtype: int64

# %%
from sklearn.linear_model import LassoLars

ri = LassoLars(alpha=.1)

X = merge_ini_math_encoded[['school', 'sex', 'address', 'Pstatus', 'age', 'Medu', 'Fedu']]
y = merge_ini_math_encoded['G3']

ri.fit(X, y)
# Out:
# LassoLars(alpha=0.1)

# %%
d ={'school': 0, 'sex': 0, 'age': 15, 'address': 1, 'Pstatus': 0, 'Medu': 4, 'Fedu': 3}
pred = pd.DataFrame(d, index=[0])

# data = {'a' : 1, 'b' : 2, 'c' : 3}
# pd.DataFrame(data, index=[0]

# %%
pred
# Out:
#    school  sex  age  address  Pstatus  Medu  Fedu
# 0       0    0   15        1        0     4     3

# %%
final_value = ri.predict(pred)

# %%
final_value
# Out:
# array([10.41518987])

# %%
plt.figure(figsize=(10,10))
ax = sns.countplot(x="G3_x", data=merge_math_english)
plt.xlabel("G3_math")
plt.ylabel("Scores achieved by students")
plt.title("Math scores, G3")
# Out:
# Text(0.5, 1.0, 'Math scores, G3')

# %%
plt.figure(figsize=(10,10))
ax = sns.countplot(x="G3_y", data=merge_math_english)
plt.xlabel("G3_english")
plt.ylabel("Scores achieved by students")
plt.title("English scores, G3")
# Out:
# Text(0.5, 1.0, 'English scores, G3')

# %%
merge_math_english[['G3_x', 'G3_y']].corr()['G3_y']
# Out:
# G3_x    0.243451
# G3_y    1.000000
# Name: G3_y, dtype: float64

# %%
merge_ini_math = pd.merge(d_s, d_s_m, how='inner', on='Student Id')

# %%
plt.figure(figsize=(10,10))
ax = sns.countplot(x="G3", hue='sex', data=merge_ini_math)
plt.xlabel("G3_math")
plt.ylabel("Number of students achieving scores")
plt.title("Math scores, G3")
# Out:
# Text(0.5, 1.0, 'Math scores, G3')

# %%
merge_ini_math.absences.value_counts()
# Out:
# 0     115
# 2      65
# 4      53
# 6      31
# 8      22
# 10     17
# 14     12
# 12     12
# 3       8
# 7       7
# 16      7
# 18      5
# 5       5
# 20      4
# 22      3
# 13      3
# 1       3
# 9       3
# 11      3
# 15      3
# 23      1
# 24      1
# 21      1
# 25      1
# 56      1
# 26      1
# 28      1
# 30      1
# 17      1
# 38      1
# 40      1
# 54      1
# 19      1
# 75      1
# Name: absences, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=merge_ini_math, x="G3", y="absences", s=100)
plt.xlabel("G3 scores, Math")
plt.ylabel("Absences")
plt.title("Math scores with respect to absences")
# Out:
# Text(0.5, 1.0, 'Math scores with respect to absences')

# %%
ri.coef_
# Out:
# array([0., 0., 0., 0., 0., 0., 0.])

# %%
merge_ini_math_encoded[['school', 'sex', 'address', 'Pstatus', 'age', 'Medu', 'Fedu', 'G1','G2','G3']].corr()['G3']
# Out:
# school    -0.045017
# sex        0.103456
# address    0.105756
# Pstatus   -0.058009
# age       -0.161579
# Medu       0.217147
# Fedu       0.152457
# G1         0.801468
# G2         0.904868
# G3         1.000000
# Name: G3, dtype: float64

# %%
merge_math_english['Decile_rank_math'] = pd.qcut(merge_math_english['G3_x'], 10, labels=False)
merge_math_english['Decile_rank_english'] = pd.qcut(merge_math_english['G3_y'], 7, labels=False)

# %%
merge_math_english.sort_values('Decile_rank_math', ascending=False).head(50)
# Out:
#      Student Id  G1_x  G2_x  G3_x  G1_y  G2_y  G3_y  Decile_rank_math  \
# 91           92    16    17    18    14    13    13                 9
# 109         110    14    15    16    15    15    14                 9
# 110         111    18    19    19    13    14    14                 9
# 113         114    18    19    19    18    17    18                 9
# 182         183    16    17    17    12    12    13                 9
# 69           70    16    16    16    15    15    15                 9
# 31           32    17    16    17    15    15    15                 9
# 32           33    17    16    16    13    14    15                 9
# 171         172    13    15    16    12    10    11                 9
# 36           37    15    16    18    14    14    14                 9
# 129         130    18    18    18    13    12    13                 9
# 374         375    19    18    19    17    18    17                 9
# ...

# %%
merge_math_english.sort_values('Decile_rank_english', ascending=True).head(60)
# Out:
#      Student Id  G1_x  G2_x  G3_x  G1_y  G2_y  G3_y  Decile_rank_math  \
# 140         141     7     9     0    10     9    10                 0
# 172         173    13    11    10    10    10     1                 3
# 173         174     8     7     0     9     8    10                 0
# 174         175    10    11     9     8     8     9                 2
# 71           72    10    10    10    11     9    10                 3
# 175         176    10     9     9     7     6     8                 2
# 361         362    13    12    12    11    10    10                 5
# 176         177    13    13    11     8     9    10                 4
# 67           68     7     7     6    10     9    10                 1
# 177         178     6     5     6     9     8     8                 1
# 169         170    14    14    14     9     8    10                 7
# 178         179    10     8     9     8     8     8                 2
# ...

# %%
len(merge_math_english[merge_math_english['Decile_rank_math'] == 9])
# Out:
# 40

# %%
len(merge_math_english[merge_math_english['Decile_rank_english'] == 0])
# Out:
# 83
